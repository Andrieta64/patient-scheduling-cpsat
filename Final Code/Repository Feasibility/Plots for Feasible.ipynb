# %%
# Importing Relevant Packages
from ortools.sat.python import cp_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import math
import random
import re
import csv
import unicodedata
from collections import defaultdict
from dataclasses import dataclass
from typing import List, Optional
from statistics import stdev
from fpdf import FPDF
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.optimize import minimize
# Out:
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\zlib1.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\abseil_dll.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\utf8_validity.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\re2.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\libprotobuf.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\highs.dll...
# load C:\Users\andri\anaconda3\Lib\site-packages\ortools\.libs\ortools.dll...

# %%
@dataclass
class Patient: # Forming the structure for the patients dataset
    id: int # Unique patient identifier
    name: str # Anonymised patient label
    age: int # Age of patient in yyears
    gender: str # Gender of patient
    admission_day: int # Day the patient was admitted in the hospital
    release_day: int # Day the patient was released from the hospital
    spec_id: int # ID of the patient's specialism
    spec_days: int # Number of days a patient requires this specialism
    prefered_capacity: int # How many number of beds it is preffered the room to have
    needs: List[int] # ID of features the patient needs
    prefers: List[int] # ID of features the patient prefers

@dataclass
class Room: # Forming the structure for the room dataset
    id: int # Unique room identifier
    room_number: int # Room number in hospital
    department: int # ID of the department the room belongs
    capacity: int # How many beds the room has
    gender: str # Gender the room is designated for
    has: List[int] # Equipment the room has
    spec_ids: List[int] # IDs of the specialisms supported by this room
    penalties: List[int] # Penalties of specialisms

# %%
# Function to build hospital data from CSV files
def build_hospital_data():
    # Read room and patient data from CSV files into pandas DataFrames
    rooms_df = pd.read_csv("cleaned_rooms1.csv")
    patients_df = pd.read_csv("cleaned_patients1.csv")

    # Create a list of Room objects from the rooms DataFrame
    rooms = [
        Room(
            id=i, # Assign a unique ID to each room
            room_number=int(row["RoomNumber"]), # Get room number
            department=int(row["DepartmentID"]), # Get department ID
            capacity=int(row["Capacity"]), # Get room capacity
            gender=row["Gender"], # Get gender designation
            has=[ # List of equipment the room has (assuming order: Telemetry, Oxygen, Nitrogen, Television)
                int(row["Telemetry"]),
                int(row["Oxygen"]),
                int(row["Nitrogen"]),
                int(row["Television"])
            ],
            spec_ids=[ # List of specialism IDs supported by the room
                int(row["ReqSpecialism1"]),
                int(row["ReqSpecialism2"]),
                int(row["ReqSpecialism3"])
            ],
            penalties=[ # List of penalties associated with specialisms in this room
                int(row["PenaltySpecialism1"]),
                int(row["PenaltySpecialism2"]),
                int(row["PenaltySpecialism3"])
            ]
        )
        for i, row in rooms_df.iterrows() # Iterate through each row of the rooms DataFrame
    ]

    # Create a list of Patient objects from the patients DataFrame
    patients = [
        Patient(
            id=i, # Assign a unique ID to each patient
            name=row["Name"], # Get patient name
            age=int(row["Age"]), # Get patient age
            gender=row["Gender"], # Get patient gender
            admission_day=int(row["AdmissionDay"]), # Get admission day
            release_day=int(row["ReleaseDay"]), # Get release day
            spec_id=int(row["SpecialismID"]), # Get specialism ID
            spec_days=int(row["SpecialismDays"]), # Get number of days specialism is needed
            prefered_capacity=int(row["PreferredRoomCapacity"]), # Get preferred room capacity
            needs=[ # List of equipment the patient needs (assuming order: Telemetry, Oxygen, Nitrogen, Television)
                int(row["NeedsTelemetry"]),
                int(row["NeedsOxygen"]),
                int(row["NeedsNitrogen"]),
                int(row["NeedsTV"])
            ],
            prefers=[ # List of equipment the patient prefers (assuming order: Telemetry, Oxygen, Nitrogen, Television)
                int(row["PrefersTelemetry"]),
                int(row["PrefersOxygen"]),
                int(row["PrefersNitrogen"]),
                int(row["PrefersTV"])
            ]
        )
        for i, row in patients_df.iterrows() # Iterate through each row of the patients DataFrame
    ]

    # Return the lists of Room and Patient objects
    return rooms, patients

# %%
# Custom solution callback for printing the final hospital allocation
class HospitalAllocationPrinter(cp_model.CpSolverSolutionCallback):
    # Constructor to initialize the callback with necessary data
    def __init__(self, seats, patients, rooms):
        super().__init__() # Call the constructor of the parent class
        self.__seats = seats # Store the dictionary of boolean variables representing assignments
        self.__patients = patients # Store the list of patient objects
        self.__rooms = rooms # Store the list of room objects
        self.__solution_found = False # Flag to indicate if a solution has been found

    # Callback method called by the solver when an improving solution is found
    def on_solution_callback(self):
        self.__solution_found = True # Set the flag to True

    # Method to print the final solution after the solver finishes
    def print_final_solution(self, solver):
        print("\nFinal solution:") # Print a header for the final solution
        # Iterate through each room to display its assignments
        for room in self.__rooms:
            # Print room details
            print(f"\nRoom {room.id} (RoomNum: {room.room_number}, Dept: {room.department}, Capacity: {room.capacity}, Gender: {room.gender}):")
            assigned = False # Flag to check if any patient is assigned to this room
            # Iterate through each patient to see if they are assigned to the current room
            for patient in self.__patients:
                # Check if the boolean variable for this patient-room assignment is True in the final solution
                if solver.BooleanValue(self.__seats[(room.id, patient.id)]):
                    # Print patient details if assigned to this room
                    print(f"  - Patient {patient.name} (Age: {patient.age}, Gender: {patient.gender})")
                    assigned = True # Set flag to True as a patient is assigned
            # If no patient was assigned to this room, print "(empty)"
            if not assigned:
                print("  (empty)")

    # Method to check if a solution has been found
    def solution_found(self):
        return self.__solution_found

# %%
# Custom solution callback to log improving solutions found by the CP-SAT solver
class ImprovingSolutionLogger(cp_model.CpSolverSolutionCallback):
    # Constructor to initialize the logger
    def __init__(self):
        super().__init__() # Call the constructor of the parent class
        self.times = [] # List to store the elapsed time when an improving solution is found
        self.objectives = [] # List to store the objective value of improving solutions
        self.start_time = time.time() # Record the start time when the logger is initialized

    # Callback method called by the solver when an improving solution is found
    def on_solution_callback(self):
        elapsed = time.time() - self.start_time # Calculate the elapsed time since the start
        current_obj = self.ObjectiveValue() # Get the objective value of the current solution
        self.times.append(elapsed) # Append the elapsed time to the list
        self.objectives.append(current_obj) # Append the objective value to the list
        # Print the objective value and elapsed time for the improving solution
        print(f"Objective {current_obj} at {elapsed:.2f}s")

# %%
# Main function to solve the hospital allocation problem
def solve_hospital_allocation():
    # Build hospital data (rooms and patients)
    rooms, patients = build_hospital_data()

    # Determine the maximum admission day to define the planning horizon
    max_day = max(p.admission_day for p in patients)
    previous_assignment = {} # Dictionary to store the previous room assignment for each patient
    total_duration = 0 # Variable to accumulate the total solving time across all days

    all_day_logs = {}  # Dictionary to store improving solutions and status per day

    # Iterate through each day in the planning horizon
    for day in range(max_day + 1):
        print(f"\n Solving for Day {day}") # Print the current day being solved
        # Identify patients present on the current day (admission <= current day < release)
        present_patients = [p for p in patients if p.admission_day <= day < p.release_day]
        print(f"Patients present: {len(present_patients)}") # Print the number of patients present

        if not present_patients: # If no patients are present, skip to the next day
            continue

        # CP-SAT Model Definition
        model = cp_model.CpModel() # Create a new CP-SAT model
        seats = {
            # Create a boolean variable for each possible patient-room assignment on the current day
            (r.id, p.id): model.NewBoolVar(f"patient_{p.id}_in_room_{r.id}_day{day}")
            for r in rooms for p in present_patients
        }

        # Soft Constraint Violations - Lists to store boolean variables for each type of violation
        violations_preferred_capacity = [] # Violations of preferred room capacity
        violations_gender = [] # Violations of gender preference
        violations_equipment = [] # Violations of preferred equipment (re-used, consider renaming for clarity)
        equipment_violations = [] # Violations of needed equipment
        move_penalties = [] # Penalties for moving a patient to a different room
        age_violations = [] # Violations of department age limits
        violations_specialism = [] # Violations related to specialism penalties

        # Populate the violation lists based on potential assignments and penalties
        for p in present_patients:
            prev_room = previous_assignment.get(p.id, None) # Get the patient's previous room assignment
            for r in rooms:
                seat = seats[(r.id, p.id)] # The boolean variable for this patient-room assignment

                # Check for each type of soft constraint violation if this assignment is made
                if r.capacity > p.prefered_capacity:
                    violations_preferred_capacity.append(seat)
                if r.gender in ['F', 'M'] and r.gender != p.gender:
                    violations_gender.append(seat)
                if any(p.prefers[i] == 1 and r.has[i] == 0 for i in range(4)): # Assuming 4 equipment types
                    violations_equipment.append(seat)
                if any(p.needs[i] == 1 and r.has[i] == 0 for i in range(4)): # Assuming 4 equipment types
                    equipment_violations.append(seat)
                if prev_room is not None and r.id != prev_room:
                    move_penalties.append(seat)
                # Age violations based on department (assuming specific department IDs and age limits)
                if (r.department == 1 and p.age < 65) or (r.department == 4 and p.age > 16):
                    age_violations.append(seat)
                # Specialism violations based on room's supported specialisms and penalties
                if p.spec_id in r.spec_ids:
                    penalty = r.penalties[r.spec_ids.index(p.spec_id)] - 1 # Get the penalty for the specialism
                    if penalty > 0: # Add penalty proportional to the penalty value
                        violations_specialism.extend([seat] * penalty)
                else: # Add a larger penalty if the specialism is not supported
                    violations_specialism.extend([seat] * 3)

        # Hard Constraints
        # Each patient must be assigned to exactly one room
        for p in present_patients:
            model.Add(sum(seats[(r.id, p.id)] for r in rooms) == 1)
        # Each room's capacity must not be exceeded
        for r in rooms:
            model.Add(sum(seats[(r.id, p.id)] for p in present_patients) <= r.capacity)

        # Define the objective function to minimize the total weighted sum of soft constraint violations
        model.Minimize(
            3 * sum(violations_preferred_capacity) + # Weight for preferred capacity violations
            5 * sum(violations_gender) + # Weight for gender violations
            3 * sum(violations_equipment) + # Weight for preferred equipment violations
            7 * sum(age_violations) + # Weight for age violations
            10 * sum(move_penalties) + # Weight for move penalties
            10 * sum(equipment_violations) + # Weight for needed equipment violations
            4 * sum(violations_specialism) # Weight for specialism violations
        )

        # Solve the model for the current day
        solver = cp_model.CpSolver() # Create a CP-SAT solver instance
        solver.parameters.max_time_in_seconds = 500  # Set a reasonable time limit for solving
        logger = ImprovingSolutionLogger() # Create a logger to track improving solutions

        start_time = time.time() # Record the start time for solving the day
        # Solve the model using the logger callback
        status = solver.SolveWithSolutionCallback(model, logger)
        end_time = time.time() # Record the end time for solving the day

        duration = end_time - start_time # Calculate the time taken to solve the day
        total_duration += duration # Add the day's duration to the total duration

        # Print the best objective value found and the time taken
        if logger.objectives:
            print(f"Best objective for Day {day}: {logger.objectives[-1]} in {logger.times[-1]:.2f}s")
        else:
            print("No feasible solution found.") # Print message if no feasible solution is found

        # Print the final solution for the current day
        printer = HospitalAllocationPrinter(seats, present_patients, rooms)
        printer.print_final_solution(solver)

        # Store the current assignments to handle move penalties for the next day
        current_assignment = {
            p.id: r.id
            for r in rooms
            for p in present_patients
            if solver.BooleanValue(seats[(r.id, p.id)]) # Check if the patient is assigned to this room
        }
        previous_assignment = current_assignment # Update previous assignment for the next day

        # Save per-day log (times and objectives of improving solutions, and final status)
        all_day_logs[day] = {
            "times": logger.times,
            "objectives": logger.objectives,
            "status": solver.StatusName(status)
        }

    print(f"\nTotal solving time across all days: {total_duration:.2f} seconds.") # Print the total solving time
    return all_day_logs # Return the logs for all days

# %%
if __name__ == "__main__":
    # Solve the hospital allocation problem and get the logs
    logs = solve_hospital_allocation()

    # Extract best (final) objective for each day
    days = [] # List to store day numbers
    penalties = [] # List to store the best objective value (penalty) for each day

    # Iterate through the logs for each day
    for day, data in logs.items():
        if data["objectives"]:  # Check if there were any improving solutions found for the day (i.e., a feasible solution)
            days.append(day) # Add the day number to the list
            penalties.append(data["objectives"][-1])  # Append the last (best found) objective value for the day


    # Optional plot for Day 0 (or any other specific day, currently set to day 19)
    import matplotlib.pyplot as plt # Import matplotlib for plotting
    day_to_plot = 19 # Define the specific day to plot
    # Check if logs exist for the specified day and if there are objectives (solutions) for that day
    if day_to_plot in logs and logs[day_to_plot]["objectives"]:
        day_data = logs[day_to_plot] # Get the data for the specified day
        # Plot the objective value progress over time for the selected day
        plt.plot(day_data["times"], day_data["objectives"], marker='o') # Create a line plot with markers
        plt.xlabel("Time (s)") # Set the x-axis label
        plt.ylabel("Objective Value") # Set the y-axis label
        plt.title(f"Optimization Progress Over Time (Day {day_to_plot})") # Set the title of the plot
        plt.savefig("feasible19.png", dpi=300) # Save the plot to a file
        plt.grid(True) # Add a grid to the plot
        plt.show() # Display the plot
# Out:
#  Solving for Day 0
# Patients present: 70
# Objective 1059.0 at 0.50s
# Objective 556.0 at 0.71s
# Objective 87.0 at 0.78s
# Best objective for Day 0: 87.0 in 0.78s
#
# Final solution:
#
# Room 0 (RoomNum: 11, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient34 (Age: 74, Gender: F)
#
# Room 1 (RoomNum: 12, Dept: 1, Capacity: 1, Gender: D):
#   - Patient Patient39 (Age: 106, Gender: F)
#
# Room 2 (RoomNum: 13, Dept: 1, Capacity: 1, Gender: N):
#   - Patient Patient65 (Age: 103, Gender: F)
#
# Room 3 (RoomNum: 14, Dept: 1, Capacity: 1, Gender: F):
#   (empty)
#
# Room 4 (RoomNum: 15, Dept: 1, Capacity: 2, Gender: D):
#   (empty)
#
# Room 5 (RoomNum: 16, Dept: 1, Capacity: 2, Gender: N):
#   (empty)
#
# Room 6 (RoomNum: 17, Dept: 1, Capacity: 2, Gender: D):
#   (empty)
#
# Room 7 (RoomNum: 18, Dept: 1, Capacity: 2, Gender: N):
#   (empty)
#
# Room 8 (RoomNum: 19, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient13 (Age: 71, Gender: F)
#
# Room 9 (RoomNum: 110, Dept: 1, Capacity: 2, Gender: M):
#   (empty)
#
# Room 10 (RoomNum: 111, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient18 (Age: 81, Gender: M)
#   - Patient Patient23 (Age: 92, Gender: M)
#
# Room 11 (RoomNum: 112, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient21 (Age: 99, Gender: M)
#   - Patient Patient53 (Age: 83, Gender: M)
#
# Room 12 (RoomNum: 113, Dept: 1, Capacity: 2, Gender: M):
#   (empty)
#
# Room 13 (RoomNum: 114, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient15 (Age: 96, Gender: F)
#   - Patient Patient55 (Age: 92, Gender: F)
#   - Patient Patient70 (Age: 90, Gender: F)
#
# Room 14 (RoomNum: 115, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 15 (RoomNum: 116, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 16 (RoomNum: 117, Dept: 1, Capacity: 4, Gender: N):
#   (empty)
#
# Room 17 (RoomNum: 118, Dept: 1, Capacity: 4, Gender: N):
#   (empty)
#
# Room 18 (RoomNum: 119, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 19 (RoomNum: 120, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 20 (RoomNum: 121, Dept: 1, Capacity: 4, Gender: D):
#   - Patient Patient30 (Age: 68, Gender: M)
#
# Room 21 (RoomNum: 122, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 22 (RoomNum: 123, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient10 (Age: 83, Gender: F)
#   - Patient Patient42 (Age: 85, Gender: F)
#   - Patient Patient47 (Age: 86, Gender: F)
#
# Room 23 (RoomNum: 124, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient57 (Age: 105, Gender: M)
#   - Patient Patient61 (Age: 104, Gender: M)
#   - Patient Patient68 (Age: 88, Gender: M)
#
# Room 24 (RoomNum: 125, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient4 (Age: 104, Gender: F)
#   - Patient Patient25 (Age: 88, Gender: F)
#   - Patient Patient29 (Age: 98, Gender: M)
#   - Patient Patient50 (Age: 69, Gender: F)
#
# Room 25 (RoomNum: 126, Dept: 1, Capacity: 4, Gender: N):
#   (empty)
#
# Room 26 (RoomNum: 127, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 27 (RoomNum: 228, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient64 (Age: 61, Gender: M)
#
# Room 28 (RoomNum: 229, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient56 (Age: 109, Gender: M)
#
# Room 29 (RoomNum: 230, Dept: 2, Capacity: 1, Gender: N):
#   - Patient Patient38 (Age: 106, Gender: F)
#
# Room 30 (RoomNum: 231, Dept: 2, Capacity: 1, Gender: F):
#   - Patient Patient28 (Age: 53, Gender: F)
#
# Room 31 (RoomNum: 232, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient11 (Age: 34, Gender: M)
#
# Room 32 (RoomNum: 233, Dept: 2, Capacity: 2, Gender: M):
#   (empty)
#
# Room 33 (RoomNum: 234, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient41 (Age: 96, Gender: F)
#   - Patient Patient43 (Age: 24, Gender: F)
#
# Room 34 (RoomNum: 235, Dept: 2, Capacity: 2, Gender: M):
#   (empty)
#
# Room 35 (RoomNum: 236, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient3 (Age: 96, Gender: M)
#
# Room 36 (RoomNum: 237, Dept: 2, Capacity: 2, Gender: F):
#   - Patient Patient36 (Age: 109, Gender: F)
#   - Patient Patient66 (Age: 32, Gender: F)
#
# Room 37 (RoomNum: 238, Dept: 2, Capacity: 2, Gender: D):
#   (empty)
#
# Room 38 (RoomNum: 239, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient62 (Age: 91, Gender: M)
#   - Patient Patient67 (Age: 55, Gender: M)
#
# Room 39 (RoomNum: 240, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient6 (Age: 19, Gender: M)
#   - Patient Patient9 (Age: 59, Gender: M)
#
# Room 40 (RoomNum: 241, Dept: 2, Capacity: 2, Gender: M):
#   (empty)
#
# Room 41 (RoomNum: 242, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient5 (Age: 28, Gender: M)
#   - Patient Patient19 (Age: 22, Gender: M)
#   - Patient Patient33 (Age: 20, Gender: M)
#   - Patient Patient52 (Age: 16, Gender: M)
#
# Room 42 (RoomNum: 243, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 43 (RoomNum: 244, Dept: 2, Capacity: 4, Gender: F):
#   (empty)
#
# Room 44 (RoomNum: 245, Dept: 2, Capacity: 4, Gender: N):
#   (empty)
#
# Room 45 (RoomNum: 246, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 46 (RoomNum: 247, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient12 (Age: 8, Gender: M)
#   - Patient Patient17 (Age: 64, Gender: M)
#   - Patient Patient51 (Age: 75, Gender: M)
#   - Patient Patient59 (Age: 27, Gender: M)
#
# Room 47 (RoomNum: 248, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 48 (RoomNum: 249, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient1 (Age: 55, Gender: F)
#   - Patient Patient8 (Age: 21, Gender: F)
#   - Patient Patient24 (Age: 85, Gender: F)
#   - Patient Patient54 (Age: 39, Gender: F)
#
# Room 49 (RoomNum: 250, Dept: 2, Capacity: 4, Gender: D):
#   (empty)
#
# Room 50 (RoomNum: 251, Dept: 2, Capacity: 4, Gender: D):
#   (empty)
#
# Room 51 (RoomNum: 252, Dept: 2, Capacity: 4, Gender: N):
#   (empty)
#
# Room 52 (RoomNum: 253, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 53 (RoomNum: 254, Dept: 2, Capacity: 4, Gender: F):
#   (empty)
#
# Room 54 (RoomNum: 355, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient14 (Age: 0, Gender: M)
#
# Room 55 (RoomNum: 356, Dept: 3, Capacity: 1, Gender: M):
#   (empty)
#
# Room 56 (RoomNum: 357, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient60 (Age: 94, Gender: M)
#
# Room 57 (RoomNum: 358, Dept: 3, Capacity: 2, Gender: D):
#   (empty)
#
# Room 58 (RoomNum: 359, Dept: 3, Capacity: 2, Gender: N):
#   (empty)
#
# Room 59 (RoomNum: 360, Dept: 3, Capacity: 2, Gender: M):
#   (empty)
#
# Room 60 (RoomNum: 361, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient32 (Age: 80, Gender: F)
#   - Patient Patient49 (Age: 29, Gender: M)
#
# Room 61 (RoomNum: 362, Dept: 3, Capacity: 2, Gender: M):
#   (empty)
#
# Room 62 (RoomNum: 363, Dept: 3, Capacity: 2, Gender: F):
#   - Patient Patient44 (Age: 63, Gender: F)
#
# Room 63 (RoomNum: 364, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 64 (RoomNum: 365, Dept: 3, Capacity: 4, Gender: D):
#   (empty)
#
# Room 65 (RoomNum: 366, Dept: 3, Capacity: 4, Gender: D):
#   (empty)
#
# Room 66 (RoomNum: 367, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient27 (Age: 21, Gender: F)
#   - Patient Patient31 (Age: 4, Gender: F)
#
# Room 67 (RoomNum: 368, Dept: 3, Capacity: 4, Gender: M):
#   (empty)
#
# Room 68 (RoomNum: 369, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 69 (RoomNum: 370, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient35 (Age: 77, Gender: F)
#   - Patient Patient46 (Age: 95, Gender: M)
#   - Patient Patient48 (Age: 88, Gender: F)
#   - Patient Patient69 (Age: 49, Gender: F)
#
# Room 70 (RoomNum: 371, Dept: 3, Capacity: 4, Gender: F):
#   (empty)
#
# Room 71 (RoomNum: 372, Dept: 3, Capacity: 4, Gender: F):
#   (empty)
#
# Room 72 (RoomNum: 373, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient16 (Age: 28, Gender: M)
#   - Patient Patient40 (Age: 3, Gender: M)
#
# Room 73 (RoomNum: 374, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient2 (Age: 50, Gender: F)
#   - Patient Patient20 (Age: 61, Gender: F)
#   - Patient Patient22 (Age: 51, Gender: F)
#   - Patient Patient37 (Age: 51, Gender: F)
#
# Room 74 (RoomNum: 375, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient7 (Age: 42, Gender: M)
#   - Patient Patient63 (Age: 107, Gender: M)
#
# Room 75 (RoomNum: 476, Dept: 4, Capacity: 1, Gender: D):
#   (empty)
#
# Room 76 (RoomNum: 477, Dept: 4, Capacity: 1, Gender: N):
#   (empty)
#
# Room 77 (RoomNum: 478, Dept: 4, Capacity: 1, Gender: N):
#   - Patient Patient58 (Age: 3, Gender: M)
#
# Room 78 (RoomNum: 479, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 79 (RoomNum: 480, Dept: 4, Capacity: 2, Gender: D):
#   (empty)
#
# Room 80 (RoomNum: 481, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 81 (RoomNum: 482, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 82 (RoomNum: 483, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 83 (RoomNum: 484, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 84 (RoomNum: 485, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 85 (RoomNum: 486, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 86 (RoomNum: 487, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 87 (RoomNum: 488, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient45 (Age: 7, Gender: M)
#
# Room 88 (RoomNum: 489, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 89 (RoomNum: 490, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 90 (RoomNum: 491, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 91 (RoomNum: 492, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 92 (RoomNum: 493, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 93 (RoomNum: 494, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 94 (RoomNum: 495, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 95 (RoomNum: 496, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 96 (RoomNum: 497, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 97 (RoomNum: 498, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 98 (RoomNum: 499, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 99 (RoomNum: 4100, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 100 (RoomNum: 4101, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 101 (RoomNum: 4102, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 102 (RoomNum: 4103, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 103 (RoomNum: 4104, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 104 (RoomNum: 4105, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient26 (Age: 1, Gender: M)
#
#  Solving for Day 1
# Patients present: 127
# Objective 2407.0 at 0.91s
# Objective 228.0 at 1.51s
# Best objective for Day 1: 228.0 in 1.51s
#
# Final solution:
#
# Room 0 (RoomNum: 11, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient34 (Age: 74, Gender: F)
#
# Room 1 (RoomNum: 12, Dept: 1, Capacity: 1, Gender: D):
#   - Patient Patient39 (Age: 106, Gender: F)
#
# Room 2 (RoomNum: 13, Dept: 1, Capacity: 1, Gender: N):
#   - Patient Patient65 (Age: 103, Gender: F)
#
# Room 3 (RoomNum: 14, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient102 (Age: 92, Gender: F)
#
# Room 4 (RoomNum: 15, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient84 (Age: 103, Gender: F)
#
# Room 5 (RoomNum: 16, Dept: 1, Capacity: 2, Gender: N):
#   (empty)
#
# Room 6 (RoomNum: 17, Dept: 1, Capacity: 2, Gender: D):
#   (empty)
#
# Room 7 (RoomNum: 18, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient95 (Age: 65, Gender: F)
#
# Room 8 (RoomNum: 19, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient13 (Age: 71, Gender: F)
#   - Patient Patient86 (Age: 109, Gender: F)
#
# Room 9 (RoomNum: 110, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient94 (Age: 103, Gender: M)
#
# Room 10 (RoomNum: 111, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient18 (Age: 81, Gender: M)
#   - Patient Patient23 (Age: 92, Gender: M)
#
# Room 11 (RoomNum: 112, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient21 (Age: 99, Gender: M)
#   - Patient Patient53 (Age: 83, Gender: M)
#
# Room 12 (RoomNum: 113, Dept: 1, Capacity: 2, Gender: M):
#   (empty)
#
# Room 13 (RoomNum: 114, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient15 (Age: 96, Gender: F)
#   - Patient Patient55 (Age: 92, Gender: F)
#   - Patient Patient92 (Age: 79, Gender: F)
#   - Patient Patient112 (Age: 106, Gender: F)
#
# Room 14 (RoomNum: 115, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 15 (RoomNum: 116, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient83 (Age: 93, Gender: F)
#
# Room 16 (RoomNum: 117, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient120 (Age: 102, Gender: F)
#
# Room 17 (RoomNum: 118, Dept: 1, Capacity: 4, Gender: N):
#   (empty)
#
# Room 18 (RoomNum: 119, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 19 (RoomNum: 120, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 20 (RoomNum: 121, Dept: 1, Capacity: 4, Gender: D):
#   - Patient Patient30 (Age: 68, Gender: M)
#   - Patient Patient93 (Age: 106, Gender: F)
#
# Room 21 (RoomNum: 122, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 22 (RoomNum: 123, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient10 (Age: 83, Gender: F)
#   - Patient Patient42 (Age: 85, Gender: F)
#   - Patient Patient47 (Age: 86, Gender: F)
#   - Patient Patient97 (Age: 95, Gender: F)
#
# Room 23 (RoomNum: 124, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient57 (Age: 105, Gender: M)
#   - Patient Patient61 (Age: 104, Gender: M)
#   - Patient Patient89 (Age: 94, Gender: M)
#   - Patient Patient123 (Age: 71, Gender: F)
#
# Room 24 (RoomNum: 125, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient4 (Age: 104, Gender: F)
#   - Patient Patient25 (Age: 88, Gender: F)
#   - Patient Patient29 (Age: 98, Gender: M)
#   - Patient Patient121 (Age: 102, Gender: F)
#
# Room 25 (RoomNum: 126, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient81 (Age: 79, Gender: F)
#   - Patient Patient96 (Age: 103, Gender: F)
#   - Patient Patient127 (Age: 103, Gender: F)
#   - Patient Patient129 (Age: 100, Gender: F)
#
# Room 26 (RoomNum: 127, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient116 (Age: 93, Gender: M)
#
# Room 27 (RoomNum: 228, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient64 (Age: 61, Gender: M)
#
# Room 28 (RoomNum: 229, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient56 (Age: 109, Gender: M)
#
# Room 29 (RoomNum: 230, Dept: 2, Capacity: 1, Gender: N):
#   - Patient Patient38 (Age: 106, Gender: F)
#
# Room 30 (RoomNum: 231, Dept: 2, Capacity: 1, Gender: F):
#   - Patient Patient28 (Age: 53, Gender: F)
#
# Room 31 (RoomNum: 232, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient11 (Age: 34, Gender: M)
#   - Patient Patient104 (Age: 17, Gender: M)
#
# Room 32 (RoomNum: 233, Dept: 2, Capacity: 2, Gender: M):
#   (empty)
#
# Room 33 (RoomNum: 234, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient41 (Age: 96, Gender: F)
#   - Patient Patient76 (Age: 88, Gender: F)
#
# Room 34 (RoomNum: 235, Dept: 2, Capacity: 2, Gender: M):
#   (empty)
#
# Room 35 (RoomNum: 236, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient3 (Age: 96, Gender: M)
#   - Patient Patient108 (Age: 45, Gender: M)
#
# Room 36 (RoomNum: 237, Dept: 2, Capacity: 2, Gender: F):
#   - Patient Patient36 (Age: 109, Gender: F)
#   - Patient Patient66 (Age: 32, Gender: F)
#
# Room 37 (RoomNum: 238, Dept: 2, Capacity: 2, Gender: D):
#   - Patient Patient74 (Age: 20, Gender: M)
#   - Patient Patient119 (Age: 97, Gender: F)
#
# Room 38 (RoomNum: 239, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient62 (Age: 91, Gender: M)
#   - Patient Patient67 (Age: 55, Gender: M)
#
# Room 39 (RoomNum: 240, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient6 (Age: 19, Gender: M)
#   - Patient Patient9 (Age: 59, Gender: M)
#
# Room 40 (RoomNum: 241, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient101 (Age: 29, Gender: M)
#
# Room 41 (RoomNum: 242, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient5 (Age: 28, Gender: M)
#   - Patient Patient19 (Age: 22, Gender: M)
#   - Patient Patient33 (Age: 20, Gender: M)
#   - Patient Patient52 (Age: 16, Gender: M)
#
# Room 42 (RoomNum: 243, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient130 (Age: 25, Gender: M)
#
# Room 43 (RoomNum: 244, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient75 (Age: 24, Gender: F)
#   - Patient Patient87 (Age: 63, Gender: F)
#   - Patient Patient90 (Age: 28, Gender: F)
#   - Patient Patient107 (Age: 23, Gender: F)
#
# Room 44 (RoomNum: 245, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient72 (Age: 85, Gender: M)
#   - Patient Patient103 (Age: 38, Gender: M)
#   - Patient Patient105 (Age: 63, Gender: F)
#   - Patient Patient113 (Age: 78, Gender: F)
#
# Room 45 (RoomNum: 246, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 46 (RoomNum: 247, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient12 (Age: 8, Gender: M)
#   - Patient Patient17 (Age: 64, Gender: M)
#   - Patient Patient51 (Age: 75, Gender: M)
#   - Patient Patient59 (Age: 27, Gender: M)
#
# Room 47 (RoomNum: 248, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 48 (RoomNum: 249, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient1 (Age: 55, Gender: F)
#   - Patient Patient8 (Age: 21, Gender: F)
#   - Patient Patient24 (Age: 85, Gender: F)
#   - Patient Patient54 (Age: 39, Gender: F)
#
# Room 49 (RoomNum: 250, Dept: 2, Capacity: 4, Gender: D):
#   (empty)
#
# Room 50 (RoomNum: 251, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient73 (Age: 31, Gender: F)
#   - Patient Patient85 (Age: 29, Gender: F)
#   - Patient Patient99 (Age: 38, Gender: F)
#   - Patient Patient106 (Age: 106, Gender: M)
#
# Room 51 (RoomNum: 252, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient111 (Age: 5, Gender: F)
#
# Room 52 (RoomNum: 253, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 53 (RoomNum: 254, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient136 (Age: 2, Gender: F)
#
# Room 54 (RoomNum: 355, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient14 (Age: 0, Gender: M)
#
# Room 55 (RoomNum: 356, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient100 (Age: 88, Gender: M)
#
# Room 56 (RoomNum: 357, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient60 (Age: 94, Gender: M)
#
# Room 57 (RoomNum: 358, Dept: 3, Capacity: 2, Gender: D):
#   (empty)
#
# Room 58 (RoomNum: 359, Dept: 3, Capacity: 2, Gender: N):
#   (empty)
#
# Room 59 (RoomNum: 360, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient91 (Age: 33, Gender: M)
#   - Patient Patient132 (Age: 58, Gender: M)
#
# Room 60 (RoomNum: 361, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient32 (Age: 80, Gender: F)
#   - Patient Patient49 (Age: 29, Gender: M)
#
# Room 61 (RoomNum: 362, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient109 (Age: 40, Gender: M)
#   - Patient Patient137 (Age: 32, Gender: M)
#
# Room 62 (RoomNum: 363, Dept: 3, Capacity: 2, Gender: F):
#   - Patient Patient79 (Age: 51, Gender: F)
#   - Patient Patient117 (Age: 18, Gender: F)
#
# Room 63 (RoomNum: 364, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 64 (RoomNum: 365, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient122 (Age: 50, Gender: F)
#
# Room 65 (RoomNum: 366, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient88 (Age: 29, Gender: M)
#   - Patient Patient124 (Age: 38, Gender: F)
#
# Room 66 (RoomNum: 367, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient27 (Age: 21, Gender: F)
#   - Patient Patient31 (Age: 4, Gender: F)
#   - Patient Patient80 (Age: 4, Gender: M)
#   - Patient Patient131 (Age: 60, Gender: M)
#
# Room 67 (RoomNum: 368, Dept: 3, Capacity: 4, Gender: M):
#   (empty)
#
# Room 68 (RoomNum: 369, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 69 (RoomNum: 370, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient35 (Age: 77, Gender: F)
#   - Patient Patient48 (Age: 88, Gender: F)
#   - Patient Patient69 (Age: 49, Gender: F)
#   - Patient Patient71 (Age: 92, Gender: F)
#
# Room 70 (RoomNum: 371, Dept: 3, Capacity: 4, Gender: F):
#   (empty)
#
# Room 71 (RoomNum: 372, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient118 (Age: 35, Gender: F)
#
# Room 72 (RoomNum: 373, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient78 (Age: 38, Gender: M)
#   - Patient Patient82 (Age: 40, Gender: M)
#   - Patient Patient126 (Age: 47, Gender: M)
#   - Patient Patient128 (Age: 64, Gender: M)
#
# Room 73 (RoomNum: 374, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient2 (Age: 50, Gender: F)
#   - Patient Patient20 (Age: 61, Gender: F)
#   - Patient Patient110 (Age: 31, Gender: F)
#   - Patient Patient115 (Age: 55, Gender: F)
#
# Room 74 (RoomNum: 375, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient7 (Age: 42, Gender: M)
#   - Patient Patient63 (Age: 107, Gender: M)
#   - Patient Patient114 (Age: 30, Gender: M)
#   - Patient Patient125 (Age: 32, Gender: M)
#
# Room 75 (RoomNum: 476, Dept: 4, Capacity: 1, Gender: D):
#   (empty)
#
# Room 76 (RoomNum: 477, Dept: 4, Capacity: 1, Gender: N):
#   (empty)
#
# Room 77 (RoomNum: 478, Dept: 4, Capacity: 1, Gender: N):
#   - Patient Patient58 (Age: 3, Gender: M)
#
# Room 78 (RoomNum: 479, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 79 (RoomNum: 480, Dept: 4, Capacity: 2, Gender: D):
#   (empty)
#
# Room 80 (RoomNum: 481, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 81 (RoomNum: 482, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 82 (RoomNum: 483, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 83 (RoomNum: 484, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 84 (RoomNum: 485, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 85 (RoomNum: 486, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient98 (Age: 10, Gender: M)
#
# Room 86 (RoomNum: 487, Dept: 4, Capacity: 2, Gender: N):
#   - Patient Patient133 (Age: 42, Gender: F)
#   - Patient Patient134 (Age: 62, Gender: F)
#
# Room 87 (RoomNum: 488, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient45 (Age: 7, Gender: M)
#   - Patient Patient77 (Age: 2, Gender: M)
#
# Room 88 (RoomNum: 489, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 89 (RoomNum: 490, Dept: 4, Capacity: 4, Gender: N):
#   - Patient Patient135 (Age: 0, Gender: M)
#
# Room 90 (RoomNum: 491, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 91 (RoomNum: 492, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 92 (RoomNum: 493, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 93 (RoomNum: 494, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 94 (RoomNum: 495, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 95 (RoomNum: 496, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 96 (RoomNum: 497, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 97 (RoomNum: 498, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 98 (RoomNum: 499, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 99 (RoomNum: 4100, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 100 (RoomNum: 4101, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 101 (RoomNum: 4102, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 102 (RoomNum: 4103, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 103 (RoomNum: 4104, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 104 (RoomNum: 4105, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient26 (Age: 1, Gender: M)
#
#  Solving for Day 2
# Patients present: 163
# Objective 3764.0 at 1.37s
# Objective 2963.0 at 1.82s
# Objective 2877.0 at 1.91s
# Objective 356.0 at 2.18s
# Best objective for Day 2: 356.0 in 2.18s
#
# Final solution:
#
# Room 0 (RoomNum: 11, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient34 (Age: 74, Gender: F)
#
# Room 1 (RoomNum: 12, Dept: 1, Capacity: 1, Gender: D):
#   - Patient Patient39 (Age: 106, Gender: F)
#
# Room 2 (RoomNum: 13, Dept: 1, Capacity: 1, Gender: N):
#   - Patient Patient65 (Age: 103, Gender: F)
#
# Room 3 (RoomNum: 14, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient102 (Age: 92, Gender: F)
#
# Room 4 (RoomNum: 15, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient84 (Age: 103, Gender: F)
#
# Room 5 (RoomNum: 16, Dept: 1, Capacity: 2, Gender: N):
#   (empty)
#
# Room 6 (RoomNum: 17, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient142 (Age: 71, Gender: F)
#
# Room 7 (RoomNum: 18, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient95 (Age: 65, Gender: F)
#   - Patient Patient144 (Age: 79, Gender: F)
#
# Room 8 (RoomNum: 19, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient13 (Age: 71, Gender: F)
#   - Patient Patient86 (Age: 109, Gender: F)
#
# Room 9 (RoomNum: 110, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient94 (Age: 103, Gender: M)
#
# Room 10 (RoomNum: 111, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient18 (Age: 81, Gender: M)
#   - Patient Patient23 (Age: 92, Gender: M)
#
# Room 11 (RoomNum: 112, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient21 (Age: 99, Gender: M)
#   - Patient Patient53 (Age: 83, Gender: M)
#
# Room 12 (RoomNum: 113, Dept: 1, Capacity: 2, Gender: M):
#   (empty)
#
# Room 13 (RoomNum: 114, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient15 (Age: 96, Gender: F)
#   - Patient Patient55 (Age: 92, Gender: F)
#   - Patient Patient92 (Age: 79, Gender: F)
#   - Patient Patient112 (Age: 106, Gender: F)
#
# Room 14 (RoomNum: 115, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient148 (Age: 76, Gender: F)
#
# Room 15 (RoomNum: 116, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 16 (RoomNum: 117, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient120 (Age: 102, Gender: F)
#   - Patient Patient155 (Age: 95, Gender: F)
#   - Patient Patient171 (Age: 74, Gender: F)
#
# Room 17 (RoomNum: 118, Dept: 1, Capacity: 4, Gender: N):
#   (empty)
#
# Room 18 (RoomNum: 119, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient165 (Age: 103, Gender: M)
#
# Room 19 (RoomNum: 120, Dept: 1, Capacity: 4, Gender: F):
#   (empty)
#
# Room 20 (RoomNum: 121, Dept: 1, Capacity: 4, Gender: D):
#   - Patient Patient30 (Age: 68, Gender: M)
#   - Patient Patient93 (Age: 106, Gender: F)
#   - Patient Patient152 (Age: 80, Gender: F)
#   - Patient Patient180 (Age: 99, Gender: F)
#
# Room 21 (RoomNum: 122, Dept: 1, Capacity: 4, Gender: M):
#   (empty)
#
# Room 22 (RoomNum: 123, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient10 (Age: 83, Gender: F)
#   - Patient Patient42 (Age: 85, Gender: F)
#   - Patient Patient47 (Age: 86, Gender: F)
#   - Patient Patient97 (Age: 95, Gender: F)
#
# Room 23 (RoomNum: 124, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient57 (Age: 105, Gender: M)
#   - Patient Patient166 (Age: 94, Gender: F)
#   - Patient Patient169 (Age: 101, Gender: F)
#   - Patient Patient176 (Age: 88, Gender: F)
#
# Room 24 (RoomNum: 125, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient4 (Age: 104, Gender: F)
#   - Patient Patient29 (Age: 98, Gender: M)
#   - Patient Patient121 (Age: 102, Gender: F)
#
# Room 25 (RoomNum: 126, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient81 (Age: 79, Gender: F)
#   - Patient Patient96 (Age: 103, Gender: F)
#   - Patient Patient129 (Age: 100, Gender: F)
#   - Patient Patient154 (Age: 103, Gender: M)
#
# Room 26 (RoomNum: 127, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient116 (Age: 93, Gender: M)
#   - Patient Patient149 (Age: 99, Gender: M)
#   - Patient Patient159 (Age: 76, Gender: M)
#   - Patient Patient167 (Age: 92, Gender: M)
#
# Room 27 (RoomNum: 228, Dept: 2, Capacity: 1, Gender: M):
#   (empty)
#
# Room 28 (RoomNum: 229, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient56 (Age: 109, Gender: M)
#
# Room 29 (RoomNum: 230, Dept: 2, Capacity: 1, Gender: N):
#   - Patient Patient38 (Age: 106, Gender: F)
#
# Room 30 (RoomNum: 231, Dept: 2, Capacity: 1, Gender: F):
#   - Patient Patient28 (Age: 53, Gender: F)
#
# Room 31 (RoomNum: 232, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient11 (Age: 34, Gender: M)
#   - Patient Patient104 (Age: 17, Gender: M)
#
# Room 32 (RoomNum: 233, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient170 (Age: 20, Gender: M)
#   - Patient Patient188 (Age: 78, Gender: M)
#
# Room 33 (RoomNum: 234, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient76 (Age: 88, Gender: F)
#   - Patient Patient150 (Age: 72, Gender: M)
#
# Room 34 (RoomNum: 235, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient179 (Age: 28, Gender: M)
#
# Room 35 (RoomNum: 236, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient3 (Age: 96, Gender: M)
#   - Patient Patient108 (Age: 45, Gender: M)
#
# Room 36 (RoomNum: 237, Dept: 2, Capacity: 2, Gender: F):
#   - Patient Patient66 (Age: 32, Gender: F)
#   - Patient Patient158 (Age: 41, Gender: F)
#
# Room 37 (RoomNum: 238, Dept: 2, Capacity: 2, Gender: D):
#   - Patient Patient74 (Age: 20, Gender: M)
#   - Patient Patient119 (Age: 97, Gender: F)
#
# Room 38 (RoomNum: 239, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient62 (Age: 91, Gender: M)
#   - Patient Patient67 (Age: 55, Gender: M)
#
# Room 39 (RoomNum: 240, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient6 (Age: 19, Gender: M)
#   - Patient Patient9 (Age: 59, Gender: M)
#
# Room 40 (RoomNum: 241, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient101 (Age: 29, Gender: M)
#   - Patient Patient140 (Age: 58, Gender: M)
#
# Room 41 (RoomNum: 242, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient5 (Age: 28, Gender: M)
#   - Patient Patient19 (Age: 22, Gender: M)
#   - Patient Patient33 (Age: 20, Gender: M)
#   - Patient Patient164 (Age: 57, Gender: F)
#
# Room 42 (RoomNum: 243, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient130 (Age: 25, Gender: M)
#   - Patient Patient177 (Age: 47, Gender: M)
#   - Patient Patient186 (Age: 4, Gender: M)
#
# Room 43 (RoomNum: 244, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient75 (Age: 24, Gender: F)
#   - Patient Patient87 (Age: 63, Gender: F)
#   - Patient Patient90 (Age: 28, Gender: F)
#   - Patient Patient107 (Age: 23, Gender: F)
#
# Room 44 (RoomNum: 245, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient72 (Age: 85, Gender: M)
#   - Patient Patient103 (Age: 38, Gender: M)
#   - Patient Patient105 (Age: 63, Gender: F)
#   - Patient Patient113 (Age: 78, Gender: F)
#
# Room 45 (RoomNum: 246, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 46 (RoomNum: 247, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient17 (Age: 64, Gender: M)
#   - Patient Patient51 (Age: 75, Gender: M)
#   - Patient Patient59 (Age: 27, Gender: M)
#   - Patient Patient156 (Age: 34, Gender: M)
#
# Room 47 (RoomNum: 248, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 48 (RoomNum: 249, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient1 (Age: 55, Gender: F)
#   - Patient Patient8 (Age: 21, Gender: F)
#   - Patient Patient24 (Age: 85, Gender: F)
#   - Patient Patient54 (Age: 39, Gender: F)
#
# Room 49 (RoomNum: 250, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient161 (Age: 35, Gender: F)
#
# Room 50 (RoomNum: 251, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient85 (Age: 29, Gender: F)
#   - Patient Patient99 (Age: 38, Gender: F)
#   - Patient Patient106 (Age: 106, Gender: M)
#   - Patient Patient172 (Age: 31, Gender: F)
#
# Room 51 (RoomNum: 252, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient111 (Age: 5, Gender: F)
#   - Patient Patient141 (Age: 60, Gender: F)
#   - Patient Patient173 (Age: 35, Gender: M)
#   - Patient Patient182 (Age: 55, Gender: M)
#
# Room 52 (RoomNum: 253, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 53 (RoomNum: 254, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient136 (Age: 2, Gender: F)
#   - Patient Patient143 (Age: 103, Gender: F)
#   - Patient Patient145 (Age: 73, Gender: F)
#
# Room 54 (RoomNum: 355, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient14 (Age: 0, Gender: M)
#
# Room 55 (RoomNum: 356, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient100 (Age: 88, Gender: M)
#
# Room 56 (RoomNum: 357, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient60 (Age: 94, Gender: M)
#
# Room 57 (RoomNum: 358, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient146 (Age: 61, Gender: F)
#   - Patient Patient163 (Age: 64, Gender: F)
#
# Room 58 (RoomNum: 359, Dept: 3, Capacity: 2, Gender: N):
#   - Patient Patient139 (Age: 45, Gender: M)
#
# Room 59 (RoomNum: 360, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient91 (Age: 33, Gender: M)
#   - Patient Patient132 (Age: 58, Gender: M)
#
# Room 60 (RoomNum: 361, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient32 (Age: 80, Gender: F)
#   - Patient Patient49 (Age: 29, Gender: M)
#
# Room 61 (RoomNum: 362, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient109 (Age: 40, Gender: M)
#   - Patient Patient137 (Age: 32, Gender: M)
#
# Room 62 (RoomNum: 363, Dept: 3, Capacity: 2, Gender: F):
#   - Patient Patient79 (Age: 51, Gender: F)
#   - Patient Patient117 (Age: 18, Gender: F)
#
# Room 63 (RoomNum: 364, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient151 (Age: 49, Gender: F)
#
# Room 64 (RoomNum: 365, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient122 (Age: 50, Gender: F)
#   - Patient Patient153 (Age: 78, Gender: M)
#   - Patient Patient162 (Age: 14, Gender: F)
#   - Patient Patient184 (Age: 32, Gender: F)
#
# Room 65 (RoomNum: 366, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient88 (Age: 29, Gender: M)
#   - Patient Patient124 (Age: 38, Gender: F)
#   - Patient Patient157 (Age: 24, Gender: M)
#   - Patient Patient168 (Age: 16, Gender: F)
#
# Room 66 (RoomNum: 367, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient27 (Age: 21, Gender: F)
#   - Patient Patient31 (Age: 4, Gender: F)
#   - Patient Patient80 (Age: 4, Gender: M)
#   - Patient Patient185 (Age: 0, Gender: F)
#
# Room 67 (RoomNum: 368, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient181 (Age: 42, Gender: M)
#
# Room 68 (RoomNum: 369, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 69 (RoomNum: 370, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient35 (Age: 77, Gender: F)
#   - Patient Patient48 (Age: 88, Gender: F)
#   - Patient Patient69 (Age: 49, Gender: F)
#   - Patient Patient71 (Age: 92, Gender: F)
#
# Room 70 (RoomNum: 371, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient147 (Age: 27, Gender: F)
#
# Room 71 (RoomNum: 372, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient118 (Age: 35, Gender: F)
#   - Patient Patient138 (Age: 46, Gender: F)
#
# Room 72 (RoomNum: 373, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient78 (Age: 38, Gender: M)
#   - Patient Patient82 (Age: 40, Gender: M)
#   - Patient Patient160 (Age: 5, Gender: M)
#   - Patient Patient175 (Age: 0, Gender: M)
#
# Room 73 (RoomNum: 374, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient20 (Age: 61, Gender: F)
#   - Patient Patient110 (Age: 31, Gender: F)
#   - Patient Patient174 (Age: 21, Gender: F)
#   - Patient Patient178 (Age: 45, Gender: F)
#
# Room 74 (RoomNum: 375, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient7 (Age: 42, Gender: M)
#   - Patient Patient63 (Age: 107, Gender: M)
#   - Patient Patient114 (Age: 30, Gender: M)
#   - Patient Patient125 (Age: 32, Gender: M)
#
# Room 75 (RoomNum: 476, Dept: 4, Capacity: 1, Gender: D):
#   (empty)
#
# Room 76 (RoomNum: 477, Dept: 4, Capacity: 1, Gender: N):
#   (empty)
#
# Room 77 (RoomNum: 478, Dept: 4, Capacity: 1, Gender: N):
#   - Patient Patient58 (Age: 3, Gender: M)
#
# Room 78 (RoomNum: 479, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 79 (RoomNum: 480, Dept: 4, Capacity: 2, Gender: D):
#   (empty)
#
# Room 80 (RoomNum: 481, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 81 (RoomNum: 482, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 82 (RoomNum: 483, Dept: 4, Capacity: 2, Gender: M):
#   (empty)
#
# Room 83 (RoomNum: 484, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 84 (RoomNum: 485, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient183 (Age: 60, Gender: M)
#   - Patient Patient190 (Age: 13, Gender: M)
#
# Room 85 (RoomNum: 486, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient98 (Age: 10, Gender: M)
#
# Room 86 (RoomNum: 487, Dept: 4, Capacity: 2, Gender: N):
#   - Patient Patient133 (Age: 42, Gender: F)
#   - Patient Patient134 (Age: 62, Gender: F)
#
# Room 87 (RoomNum: 488, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient45 (Age: 7, Gender: M)
#   - Patient Patient77 (Age: 2, Gender: M)
#   - Patient Patient187 (Age: 0, Gender: F)
#
# Room 88 (RoomNum: 489, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 89 (RoomNum: 490, Dept: 4, Capacity: 4, Gender: N):
#   - Patient Patient135 (Age: 0, Gender: M)
#   - Patient Patient189 (Age: 15, Gender: M)
#
# Room 90 (RoomNum: 491, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 91 (RoomNum: 492, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 92 (RoomNum: 493, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 93 (RoomNum: 494, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 94 (RoomNum: 495, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 95 (RoomNum: 496, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 96 (RoomNum: 497, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 97 (RoomNum: 498, Dept: 4, Capacity: 4, Gender: F):
#   (empty)
#
# Room 98 (RoomNum: 499, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 99 (RoomNum: 4100, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 100 (RoomNum: 4101, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 101 (RoomNum: 4102, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 102 (RoomNum: 4103, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 103 (RoomNum: 4104, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 104 (RoomNum: 4105, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient26 (Age: 1, Gender: M)
#
#  Solving for Day 3
# Patients present: 225
# Objective 5117.0 at 3.08s
# Objective 4413.0 at 3.63s
# Objective 4247.0 at 3.63s
# Objective 3980.0 at 3.64s
# Objective 3975.0 at 3.68s
# Objective 3973.0 at 3.71s
# Objective 3972.0 at 3.71s
# Objective 3964.0 at 3.72s
# Objective 3954.0 at 3.93s
# Objective 3942.0 at 3.94s
# Objective 3900.0 at 4.11s
# Objective 3789.0 at 4.16s
# Objective 2118.0 at 4.41s
# Objective 2105.0 at 4.53s
# Objective 2091.0 at 4.54s
# Objective 723.0 at 4.55s
# Best objective for Day 3: 723.0 in 4.55s
#
# Final solution:
#
# Room 0 (RoomNum: 11, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient34 (Age: 74, Gender: F)
#
# Room 1 (RoomNum: 12, Dept: 1, Capacity: 1, Gender: D):
#   - Patient Patient39 (Age: 106, Gender: F)
#
# Room 2 (RoomNum: 13, Dept: 1, Capacity: 1, Gender: N):
#   - Patient Patient65 (Age: 103, Gender: F)
#
# Room 3 (RoomNum: 14, Dept: 1, Capacity: 1, Gender: F):
#   - Patient Patient102 (Age: 92, Gender: F)
#
# Room 4 (RoomNum: 15, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient226 (Age: 96, Gender: F)
#   - Patient Patient246 (Age: 103, Gender: F)
#
# Room 5 (RoomNum: 16, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient203 (Age: 49, Gender: F)
#   - Patient Patient211 (Age: 100, Gender: F)
#
# Room 6 (RoomNum: 17, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient142 (Age: 71, Gender: F)
#   - Patient Patient205 (Age: 97, Gender: F)
#
# Room 7 (RoomNum: 18, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient95 (Age: 65, Gender: F)
#   - Patient Patient144 (Age: 79, Gender: F)
#
# Room 8 (RoomNum: 19, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient13 (Age: 71, Gender: F)
#   - Patient Patient86 (Age: 109, Gender: F)
#
# Room 9 (RoomNum: 110, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient94 (Age: 103, Gender: M)
#   - Patient Patient241 (Age: 69, Gender: M)
#
# Room 10 (RoomNum: 111, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient18 (Age: 81, Gender: M)
#   - Patient Patient23 (Age: 92, Gender: M)
#
# Room 11 (RoomNum: 112, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient21 (Age: 99, Gender: M)
#   - Patient Patient53 (Age: 83, Gender: M)
#
# Room 12 (RoomNum: 113, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient200 (Age: 75, Gender: F)
#   - Patient Patient238 (Age: 97, Gender: M)
#
# Room 13 (RoomNum: 114, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient15 (Age: 96, Gender: F)
#   - Patient Patient55 (Age: 92, Gender: F)
#   - Patient Patient92 (Age: 79, Gender: F)
#   - Patient Patient112 (Age: 106, Gender: F)
#
# Room 14 (RoomNum: 115, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient148 (Age: 76, Gender: F)
#
# Room 15 (RoomNum: 116, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient197 (Age: 93, Gender: F)
#   - Patient Patient231 (Age: 69, Gender: F)
#   - Patient Patient236 (Age: 107, Gender: F)
#   - Patient Patient239 (Age: 92, Gender: F)
#
# Room 16 (RoomNum: 117, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient120 (Age: 102, Gender: F)
#   - Patient Patient155 (Age: 95, Gender: F)
#   - Patient Patient171 (Age: 74, Gender: F)
#   - Patient Patient195 (Age: 70, Gender: F)
#
# Room 17 (RoomNum: 118, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient191 (Age: 82, Gender: F)
#   - Patient Patient217 (Age: 69, Gender: F)
#   - Patient Patient229 (Age: 73, Gender: F)
#
# Room 18 (RoomNum: 119, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient243 (Age: 105, Gender: M)
#   - Patient Patient244 (Age: 43, Gender: M)
#   - Patient Patient251 (Age: 86, Gender: M)
#   - Patient Patient260 (Age: 47, Gender: M)
#
# Room 19 (RoomNum: 120, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient201 (Age: 78, Gender: F)
#
# Room 20 (RoomNum: 121, Dept: 1, Capacity: 4, Gender: D):
#   - Patient Patient30 (Age: 68, Gender: M)
#   - Patient Patient93 (Age: 106, Gender: F)
#   - Patient Patient152 (Age: 80, Gender: F)
#   - Patient Patient180 (Age: 99, Gender: F)
#
# Room 21 (RoomNum: 122, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient216 (Age: 100, Gender: M)
#
# Room 22 (RoomNum: 123, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient10 (Age: 83, Gender: F)
#   - Patient Patient42 (Age: 85, Gender: F)
#   - Patient Patient47 (Age: 86, Gender: F)
#   - Patient Patient97 (Age: 95, Gender: F)
#
# Room 23 (RoomNum: 124, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient57 (Age: 105, Gender: M)
#   - Patient Patient166 (Age: 94, Gender: F)
#   - Patient Patient169 (Age: 101, Gender: F)
#   - Patient Patient176 (Age: 88, Gender: F)
#
# Room 24 (RoomNum: 125, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient4 (Age: 104, Gender: F)
#   - Patient Patient29 (Age: 98, Gender: M)
#   - Patient Patient121 (Age: 102, Gender: F)
#   - Patient Patient253 (Age: 70, Gender: F)
#
# Room 25 (RoomNum: 126, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient81 (Age: 79, Gender: F)
#   - Patient Patient96 (Age: 103, Gender: F)
#   - Patient Patient154 (Age: 103, Gender: M)
#   - Patient Patient240 (Age: 88, Gender: M)
#
# Room 26 (RoomNum: 127, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient116 (Age: 93, Gender: M)
#   - Patient Patient149 (Age: 99, Gender: M)
#   - Patient Patient159 (Age: 76, Gender: M)
#   - Patient Patient220 (Age: 55, Gender: M)
#
# Room 27 (RoomNum: 228, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient215 (Age: 8, Gender: M)
#
# Room 28 (RoomNum: 229, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient56 (Age: 109, Gender: M)
#
# Room 29 (RoomNum: 230, Dept: 2, Capacity: 1, Gender: N):
#   - Patient Patient38 (Age: 106, Gender: F)
#
# Room 30 (RoomNum: 231, Dept: 2, Capacity: 1, Gender: F):
#   - Patient Patient28 (Age: 53, Gender: F)
#
# Room 31 (RoomNum: 232, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient11 (Age: 34, Gender: M)
#   - Patient Patient104 (Age: 17, Gender: M)
#
# Room 32 (RoomNum: 233, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient170 (Age: 20, Gender: M)
#   - Patient Patient188 (Age: 78, Gender: M)
#
# Room 33 (RoomNum: 234, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient76 (Age: 88, Gender: F)
#   - Patient Patient150 (Age: 72, Gender: M)
#
# Room 34 (RoomNum: 235, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient179 (Age: 28, Gender: M)
#   - Patient Patient198 (Age: 31, Gender: M)
#
# Room 35 (RoomNum: 236, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient3 (Age: 96, Gender: M)
#   - Patient Patient108 (Age: 45, Gender: M)
#
# Room 36 (RoomNum: 237, Dept: 2, Capacity: 2, Gender: F):
#   - Patient Patient66 (Age: 32, Gender: F)
#   - Patient Patient158 (Age: 41, Gender: F)
#
# Room 37 (RoomNum: 238, Dept: 2, Capacity: 2, Gender: D):
#   - Patient Patient74 (Age: 20, Gender: M)
#   - Patient Patient119 (Age: 97, Gender: F)
#
# Room 38 (RoomNum: 239, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient62 (Age: 91, Gender: M)
#   - Patient Patient67 (Age: 55, Gender: M)
#
# Room 39 (RoomNum: 240, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient6 (Age: 19, Gender: M)
#   - Patient Patient9 (Age: 59, Gender: M)
#
# Room 40 (RoomNum: 241, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient101 (Age: 29, Gender: M)
#   - Patient Patient212 (Age: 59, Gender: M)
#
# Room 41 (RoomNum: 242, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient5 (Age: 28, Gender: M)
#   - Patient Patient19 (Age: 22, Gender: M)
#   - Patient Patient33 (Age: 20, Gender: M)
#   - Patient Patient164 (Age: 57, Gender: F)
#
# Room 42 (RoomNum: 243, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient130 (Age: 25, Gender: M)
#   - Patient Patient177 (Age: 47, Gender: M)
#   - Patient Patient223 (Age: 14, Gender: M)
#   - Patient Patient234 (Age: 46, Gender: M)
#
# Room 43 (RoomNum: 244, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient75 (Age: 24, Gender: F)
#   - Patient Patient87 (Age: 63, Gender: F)
#   - Patient Patient90 (Age: 28, Gender: F)
#   - Patient Patient107 (Age: 23, Gender: F)
#
# Room 44 (RoomNum: 245, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient72 (Age: 85, Gender: M)
#   - Patient Patient103 (Age: 38, Gender: M)
#   - Patient Patient105 (Age: 63, Gender: F)
#   - Patient Patient113 (Age: 78, Gender: F)
#
# Room 45 (RoomNum: 246, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient247 (Age: 39, Gender: M)
#
# Room 46 (RoomNum: 247, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient17 (Age: 64, Gender: M)
#   - Patient Patient51 (Age: 75, Gender: M)
#   - Patient Patient59 (Age: 27, Gender: M)
#   - Patient Patient156 (Age: 34, Gender: M)
#
# Room 47 (RoomNum: 248, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient204 (Age: 61, Gender: F)
#   - Patient Patient219 (Age: 33, Gender: F)
#   - Patient Patient230 (Age: 66, Gender: M)
#   - Patient Patient235 (Age: 95, Gender: M)
#
# Room 48 (RoomNum: 249, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient1 (Age: 55, Gender: F)
#   - Patient Patient8 (Age: 21, Gender: F)
#   - Patient Patient24 (Age: 85, Gender: F)
#   - Patient Patient54 (Age: 39, Gender: F)
#
# Room 49 (RoomNum: 250, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient161 (Age: 35, Gender: F)
#   - Patient Patient206 (Age: 32, Gender: M)
#   - Patient Patient209 (Age: 76, Gender: F)
#   - Patient Patient263 (Age: 60, Gender: F)
#
# Room 50 (RoomNum: 251, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient85 (Age: 29, Gender: F)
#   - Patient Patient106 (Age: 106, Gender: M)
#   - Patient Patient172 (Age: 31, Gender: F)
#   - Patient Patient194 (Age: 23, Gender: M)
#
# Room 51 (RoomNum: 252, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient111 (Age: 5, Gender: F)
#   - Patient Patient141 (Age: 60, Gender: F)
#   - Patient Patient173 (Age: 35, Gender: M)
#   - Patient Patient182 (Age: 55, Gender: M)
#
# Room 52 (RoomNum: 253, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 53 (RoomNum: 254, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient136 (Age: 2, Gender: F)
#   - Patient Patient143 (Age: 103, Gender: F)
#   - Patient Patient145 (Age: 73, Gender: F)
#   - Patient Patient252 (Age: 20, Gender: F)
#
# Room 54 (RoomNum: 355, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient14 (Age: 0, Gender: M)
#
# Room 55 (RoomNum: 356, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient100 (Age: 88, Gender: M)
#
# Room 56 (RoomNum: 357, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient60 (Age: 94, Gender: M)
#
# Room 57 (RoomNum: 358, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient146 (Age: 61, Gender: F)
#   - Patient Patient163 (Age: 64, Gender: F)
#
# Room 58 (RoomNum: 359, Dept: 3, Capacity: 2, Gender: N):
#   - Patient Patient139 (Age: 45, Gender: M)
#   - Patient Patient249 (Age: 105, Gender: F)
#
# Room 59 (RoomNum: 360, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient91 (Age: 33, Gender: M)
#   - Patient Patient199 (Age: 91, Gender: M)
#
# Room 60 (RoomNum: 361, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient32 (Age: 80, Gender: F)
#   - Patient Patient49 (Age: 29, Gender: M)
#
# Room 61 (RoomNum: 362, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient109 (Age: 40, Gender: M)
#   - Patient Patient137 (Age: 32, Gender: M)
#
# Room 62 (RoomNum: 363, Dept: 3, Capacity: 2, Gender: F):
#   - Patient Patient79 (Age: 51, Gender: F)
#   - Patient Patient117 (Age: 18, Gender: F)
#
# Room 63 (RoomNum: 364, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient151 (Age: 49, Gender: F)
#   - Patient Patient259 (Age: 42, Gender: F)
#
# Room 64 (RoomNum: 365, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient122 (Age: 50, Gender: F)
#   - Patient Patient153 (Age: 78, Gender: M)
#   - Patient Patient162 (Age: 14, Gender: F)
#   - Patient Patient184 (Age: 32, Gender: F)
#
# Room 65 (RoomNum: 366, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient124 (Age: 38, Gender: F)
#   - Patient Patient157 (Age: 24, Gender: M)
#   - Patient Patient168 (Age: 16, Gender: F)
#   - Patient Patient232 (Age: 20, Gender: F)
#
# Room 66 (RoomNum: 367, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient27 (Age: 21, Gender: F)
#   - Patient Patient31 (Age: 4, Gender: F)
#   - Patient Patient80 (Age: 4, Gender: M)
#   - Patient Patient185 (Age: 0, Gender: F)
#
# Room 67 (RoomNum: 368, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient181 (Age: 42, Gender: M)
#   - Patient Patient237 (Age: 36, Gender: M)
#
# Room 68 (RoomNum: 369, Dept: 3, Capacity: 4, Gender: N):
#   (empty)
#
# Room 69 (RoomNum: 370, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient35 (Age: 77, Gender: F)
#   - Patient Patient48 (Age: 88, Gender: F)
#   - Patient Patient69 (Age: 49, Gender: F)
#   - Patient Patient71 (Age: 92, Gender: F)
#
# Room 70 (RoomNum: 371, Dept: 3, Capacity: 4, Gender: F):
# ...
#
# Final solution:
#
# Room 0 (RoomNum: 11, Dept: 1, Capacity: 1, Gender: F):
#   (empty)
#
# Room 1 (RoomNum: 12, Dept: 1, Capacity: 1, Gender: D):
#   (empty)
#
# Room 2 (RoomNum: 13, Dept: 1, Capacity: 1, Gender: N):
#   - Patient Patient333 (Age: 94, Gender: F)
#
# Room 3 (RoomNum: 14, Dept: 1, Capacity: 1, Gender: F):
#   (empty)
#
# Room 4 (RoomNum: 15, Dept: 1, Capacity: 2, Gender: D):
#   (empty)
#
# Room 5 (RoomNum: 16, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient203 (Age: 49, Gender: F)
#
# Room 6 (RoomNum: 17, Dept: 1, Capacity: 2, Gender: D):
#   - Patient Patient142 (Age: 71, Gender: F)
#   - Patient Patient205 (Age: 97, Gender: F)
#
# Room 7 (RoomNum: 18, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient95 (Age: 65, Gender: F)
#   - Patient Patient297 (Age: 98, Gender: F)
#
# Room 8 (RoomNum: 19, Dept: 1, Capacity: 2, Gender: N):
#   - Patient Patient275 (Age: 70, Gender: F)
#   - Patient Patient352 (Age: 97, Gender: F)
#
# Room 9 (RoomNum: 110, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient94 (Age: 103, Gender: M)
#   - Patient Patient241 (Age: 69, Gender: M)
#
# Room 10 (RoomNum: 111, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient18 (Age: 81, Gender: M)
#   - Patient Patient288 (Age: 80, Gender: F)
#
# Room 11 (RoomNum: 112, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient312 (Age: 82, Gender: M)
#   - Patient Patient344 (Age: 68, Gender: M)
#
# Room 12 (RoomNum: 113, Dept: 1, Capacity: 2, Gender: M):
#   - Patient Patient200 (Age: 75, Gender: F)
#   - Patient Patient238 (Age: 97, Gender: M)
#
# Room 13 (RoomNum: 114, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient15 (Age: 96, Gender: F)
#   - Patient Patient92 (Age: 79, Gender: F)
#   - Patient Patient264 (Age: 103, Gender: F)
#   - Patient Patient311 (Age: 96, Gender: F)
#
# Room 14 (RoomNum: 115, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient148 (Age: 76, Gender: F)
#
# Room 15 (RoomNum: 116, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient197 (Age: 93, Gender: F)
#   - Patient Patient231 (Age: 69, Gender: F)
#   - Patient Patient236 (Age: 107, Gender: F)
#   - Patient Patient239 (Age: 92, Gender: F)
#
# Room 16 (RoomNum: 117, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient120 (Age: 102, Gender: F)
#   - Patient Patient171 (Age: 74, Gender: F)
#   - Patient Patient195 (Age: 70, Gender: F)
#
# Room 17 (RoomNum: 118, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient191 (Age: 82, Gender: F)
#   - Patient Patient217 (Age: 69, Gender: F)
#   - Patient Patient229 (Age: 73, Gender: F)
#
# Room 18 (RoomNum: 119, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient243 (Age: 105, Gender: M)
#   - Patient Patient251 (Age: 86, Gender: M)
#   - Patient Patient303 (Age: 74, Gender: M)
#
# Room 19 (RoomNum: 120, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient47 (Age: 86, Gender: F)
#   - Patient Patient201 (Age: 78, Gender: F)
#
# Room 20 (RoomNum: 121, Dept: 1, Capacity: 4, Gender: D):
#   - Patient Patient152 (Age: 80, Gender: F)
#   - Patient Patient180 (Age: 99, Gender: F)
#   - Patient Patient339 (Age: 94, Gender: F)
#
# Room 21 (RoomNum: 122, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient216 (Age: 100, Gender: M)
#   - Patient Patient273 (Age: 100, Gender: M)
#
# Room 22 (RoomNum: 123, Dept: 1, Capacity: 4, Gender: F):
#   - Patient Patient97 (Age: 95, Gender: F)
#   - Patient Patient246 (Age: 103, Gender: F)
#   - Patient Patient314 (Age: 74, Gender: F)
#   - Patient Patient328 (Age: 82, Gender: F)
#
# Room 23 (RoomNum: 124, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient166 (Age: 94, Gender: F)
#   - Patient Patient169 (Age: 101, Gender: F)
#   - Patient Patient176 (Age: 88, Gender: F)
#   - Patient Patient347 (Age: 83, Gender: F)
#
# Room 24 (RoomNum: 125, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient121 (Age: 102, Gender: F)
#
# Room 25 (RoomNum: 126, Dept: 1, Capacity: 4, Gender: N):
#   - Patient Patient81 (Age: 79, Gender: F)
#   - Patient Patient96 (Age: 103, Gender: F)
#   - Patient Patient154 (Age: 103, Gender: M)
#   - Patient Patient326 (Age: 84, Gender: F)
#
# Room 26 (RoomNum: 127, Dept: 1, Capacity: 4, Gender: M):
#   - Patient Patient159 (Age: 76, Gender: M)
#   - Patient Patient294 (Age: 85, Gender: M)
#   - Patient Patient325 (Age: 90, Gender: M)
#
# Room 27 (RoomNum: 228, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient215 (Age: 8, Gender: M)
#
# Room 28 (RoomNum: 229, Dept: 2, Capacity: 1, Gender: M):
#   - Patient Patient56 (Age: 109, Gender: M)
#
# Room 29 (RoomNum: 230, Dept: 2, Capacity: 1, Gender: N):
#   - Patient Patient193 (Age: 95, Gender: F)
#
# Room 30 (RoomNum: 231, Dept: 2, Capacity: 1, Gender: F):
#   - Patient Patient28 (Age: 53, Gender: F)
#
# Room 31 (RoomNum: 232, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient104 (Age: 17, Gender: M)
#   - Patient Patient308 (Age: 92, Gender: M)
#
# Room 32 (RoomNum: 233, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient188 (Age: 78, Gender: M)
#   - Patient Patient244 (Age: 43, Gender: M)
#
# Room 33 (RoomNum: 234, Dept: 2, Capacity: 2, Gender: N):
#   - Patient Patient76 (Age: 88, Gender: F)
#   - Patient Patient150 (Age: 72, Gender: M)
#
# Room 34 (RoomNum: 235, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient299 (Age: 35, Gender: M)
#   - Patient Patient309 (Age: 95, Gender: M)
#
# Room 35 (RoomNum: 236, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient3 (Age: 96, Gender: M)
#   - Patient Patient108 (Age: 45, Gender: M)
#
# Room 36 (RoomNum: 237, Dept: 2, Capacity: 2, Gender: F):
#   - Patient Patient66 (Age: 32, Gender: F)
#   - Patient Patient158 (Age: 41, Gender: F)
#
# Room 37 (RoomNum: 238, Dept: 2, Capacity: 2, Gender: D):
#   - Patient Patient74 (Age: 20, Gender: M)
#   - Patient Patient346 (Age: 31, Gender: F)
#
# Room 38 (RoomNum: 239, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient62 (Age: 91, Gender: M)
#   - Patient Patient67 (Age: 55, Gender: M)
#
# Room 39 (RoomNum: 240, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient6 (Age: 19, Gender: M)
#   - Patient Patient9 (Age: 59, Gender: M)
#
# Room 40 (RoomNum: 241, Dept: 2, Capacity: 2, Gender: M):
#   - Patient Patient212 (Age: 59, Gender: M)
#
# Room 41 (RoomNum: 242, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient164 (Age: 57, Gender: F)
#   - Patient Patient290 (Age: 22, Gender: M)
#   - Patient Patient330 (Age: 38, Gender: M)
#   - Patient Patient338 (Age: 47, Gender: F)
#
# Room 42 (RoomNum: 243, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient130 (Age: 25, Gender: M)
#   - Patient Patient177 (Age: 47, Gender: M)
#   - Patient Patient270 (Age: 99, Gender: M)
#   - Patient Patient320 (Age: 31, Gender: M)
#
# Room 43 (RoomNum: 244, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient75 (Age: 24, Gender: F)
#   - Patient Patient87 (Age: 63, Gender: F)
#   - Patient Patient90 (Age: 28, Gender: F)
#   - Patient Patient107 (Age: 23, Gender: F)
#
# Room 44 (RoomNum: 245, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient103 (Age: 38, Gender: M)
#   - Patient Patient105 (Age: 63, Gender: F)
#   - Patient Patient113 (Age: 78, Gender: F)
#   - Patient Patient348 (Age: 30, Gender: M)
#
# Room 45 (RoomNum: 246, Dept: 2, Capacity: 4, Gender: M):
#   (empty)
#
# Room 46 (RoomNum: 247, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient156 (Age: 34, Gender: M)
#   - Patient Patient304 (Age: 22, Gender: M)
#   - Patient Patient322 (Age: 26, Gender: M)
#   - Patient Patient336 (Age: 20, Gender: M)
#
# Room 47 (RoomNum: 248, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient204 (Age: 61, Gender: F)
#   - Patient Patient235 (Age: 95, Gender: M)
#
# Room 48 (RoomNum: 249, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient331 (Age: 23, Gender: F)
#   - Patient Patient335 (Age: 18, Gender: F)
#   - Patient Patient341 (Age: 0, Gender: F)
#   - Patient Patient345 (Age: 38, Gender: F)
#
# Room 49 (RoomNum: 250, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient161 (Age: 35, Gender: F)
#   - Patient Patient206 (Age: 32, Gender: M)
#   - Patient Patient209 (Age: 76, Gender: F)
#   - Patient Patient263 (Age: 60, Gender: F)
#
# Room 50 (RoomNum: 251, Dept: 2, Capacity: 4, Gender: D):
#   - Patient Patient85 (Age: 29, Gender: F)
#   - Patient Patient106 (Age: 106, Gender: M)
#   - Patient Patient172 (Age: 31, Gender: F)
#   - Patient Patient194 (Age: 23, Gender: M)
#
# Room 51 (RoomNum: 252, Dept: 2, Capacity: 4, Gender: N):
#   - Patient Patient111 (Age: 5, Gender: F)
#   - Patient Patient141 (Age: 60, Gender: F)
#   - Patient Patient173 (Age: 35, Gender: M)
#   - Patient Patient182 (Age: 55, Gender: M)
#
# Room 52 (RoomNum: 253, Dept: 2, Capacity: 4, Gender: M):
#   - Patient Patient315 (Age: 57, Gender: F)
#   - Patient Patient321 (Age: 7, Gender: M)
#
# Room 53 (RoomNum: 254, Dept: 2, Capacity: 4, Gender: F):
#   - Patient Patient143 (Age: 103, Gender: F)
#   - Patient Patient145 (Age: 73, Gender: F)
#   - Patient Patient252 (Age: 20, Gender: F)
#   - Patient Patient349 (Age: 0, Gender: F)
#
# Room 54 (RoomNum: 355, Dept: 3, Capacity: 1, Gender: M):
#   (empty)
#
# Room 55 (RoomNum: 356, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient100 (Age: 88, Gender: M)
#
# Room 56 (RoomNum: 357, Dept: 3, Capacity: 1, Gender: M):
#   - Patient Patient282 (Age: 32, Gender: F)
#
# Room 57 (RoomNum: 358, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient146 (Age: 61, Gender: F)
#   - Patient Patient343 (Age: 20, Gender: F)
#
# Room 58 (RoomNum: 359, Dept: 3, Capacity: 2, Gender: N):
#   - Patient Patient139 (Age: 45, Gender: M)
#   - Patient Patient249 (Age: 105, Gender: F)
#
# Room 59 (RoomNum: 360, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient91 (Age: 33, Gender: M)
#   - Patient Patient199 (Age: 91, Gender: M)
#
# Room 60 (RoomNum: 361, Dept: 3, Capacity: 2, Gender: D):
#   - Patient Patient266 (Age: 29, Gender: M)
#   - Patient Patient313 (Age: 55, Gender: F)
#
# Room 61 (RoomNum: 362, Dept: 3, Capacity: 2, Gender: M):
#   - Patient Patient337 (Age: 22, Gender: M)
#
# Room 62 (RoomNum: 363, Dept: 3, Capacity: 2, Gender: F):
#   - Patient Patient324 (Age: 30, Gender: F)
#   - Patient Patient332 (Age: 87, Gender: F)
#
# Room 63 (RoomNum: 364, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient151 (Age: 49, Gender: F)
#   - Patient Patient259 (Age: 42, Gender: F)
#   - Patient Patient269 (Age: 21, Gender: F)
#   - Patient Patient334 (Age: 62, Gender: M)
#
# Room 64 (RoomNum: 365, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient122 (Age: 50, Gender: F)
#   - Patient Patient153 (Age: 78, Gender: M)
#   - Patient Patient162 (Age: 14, Gender: F)
#   - Patient Patient316 (Age: 40, Gender: F)
#
# Room 65 (RoomNum: 366, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient124 (Age: 38, Gender: F)
#   - Patient Patient157 (Age: 24, Gender: M)
#   - Patient Patient168 (Age: 16, Gender: F)
#   - Patient Patient232 (Age: 20, Gender: F)
#
# Room 66 (RoomNum: 367, Dept: 3, Capacity: 4, Gender: D):
#   - Patient Patient27 (Age: 21, Gender: F)
#   - Patient Patient31 (Age: 4, Gender: F)
#   - Patient Patient80 (Age: 4, Gender: M)
#   - Patient Patient291 (Age: 32, Gender: F)
#
# Room 67 (RoomNum: 368, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient181 (Age: 42, Gender: M)
#   - Patient Patient237 (Age: 36, Gender: M)
#
# Room 68 (RoomNum: 369, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient268 (Age: 77, Gender: F)
#   - Patient Patient285 (Age: 64, Gender: F)
#   - Patient Patient301 (Age: 36, Gender: F)
#
# Room 69 (RoomNum: 370, Dept: 3, Capacity: 4, Gender: N):
#   - Patient Patient35 (Age: 77, Gender: F)
#   - Patient Patient48 (Age: 88, Gender: F)
#   - Patient Patient71 (Age: 92, Gender: F)
#   - Patient Patient307 (Age: 26, Gender: F)
#
# Room 70 (RoomNum: 371, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient281 (Age: 45, Gender: F)
#
# Room 71 (RoomNum: 372, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient118 (Age: 35, Gender: F)
#   - Patient Patient250 (Age: 24, Gender: F)
#   - Patient Patient257 (Age: 97, Gender: F)
#   - Patient Patient287 (Age: 12, Gender: F)
#
# Room 72 (RoomNum: 373, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient160 (Age: 5, Gender: M)
#   - Patient Patient210 (Age: 3, Gender: M)
#   - Patient Patient260 (Age: 47, Gender: M)
#   - Patient Patient340 (Age: 95, Gender: M)
#
# Room 73 (RoomNum: 374, Dept: 3, Capacity: 4, Gender: F):
#   - Patient Patient178 (Age: 45, Gender: F)
#   - Patient Patient296 (Age: 38, Gender: F)
#   - Patient Patient323 (Age: 4, Gender: F)
#   - Patient Patient342 (Age: 42, Gender: F)
#
# Room 74 (RoomNum: 375, Dept: 3, Capacity: 4, Gender: M):
#   - Patient Patient7 (Age: 42, Gender: M)
#   - Patient Patient63 (Age: 107, Gender: M)
#   - Patient Patient114 (Age: 30, Gender: M)
#   - Patient Patient125 (Age: 32, Gender: M)
#
# Room 75 (RoomNum: 476, Dept: 4, Capacity: 1, Gender: D):
#   - Patient Patient242 (Age: 8, Gender: F)
#
# Room 76 (RoomNum: 477, Dept: 4, Capacity: 1, Gender: N):
#   - Patient Patient248 (Age: 14, Gender: F)
#
# Room 77 (RoomNum: 478, Dept: 4, Capacity: 1, Gender: N):
#   - Patient Patient350 (Age: 14, Gender: M)
#
# Room 78 (RoomNum: 479, Dept: 4, Capacity: 2, Gender: N):
#   (empty)
#
# Room 79 (RoomNum: 480, Dept: 4, Capacity: 2, Gender: D):
#   - Patient Patient227 (Age: 9, Gender: M)
#   - Patient Patient255 (Age: 38, Gender: F)
#
# Room 80 (RoomNum: 481, Dept: 4, Capacity: 2, Gender: N):
#   - Patient Patient300 (Age: 36, Gender: F)
#
# Room 81 (RoomNum: 482, Dept: 4, Capacity: 2, Gender: F):
#   - Patient Patient292 (Age: 4, Gender: F)
#   - Patient Patient306 (Age: 98, Gender: F)
#
# Room 82 (RoomNum: 483, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient327 (Age: 13, Gender: M)
#
# Room 83 (RoomNum: 484, Dept: 4, Capacity: 2, Gender: F):
#   (empty)
#
# Room 84 (RoomNum: 485, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient183 (Age: 60, Gender: M)
#   - Patient Patient190 (Age: 13, Gender: M)
#
# Room 85 (RoomNum: 486, Dept: 4, Capacity: 2, Gender: M):
#   - Patient Patient98 (Age: 10, Gender: M)
#   - Patient Patient207 (Age: 6, Gender: M)
#
# Room 86 (RoomNum: 487, Dept: 4, Capacity: 2, Gender: N):
#   - Patient Patient351 (Age: 3, Gender: M)
#
# Room 87 (RoomNum: 488, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient187 (Age: 0, Gender: F)
#   - Patient Patient256 (Age: 59, Gender: F)
#   - Patient Patient277 (Age: 38, Gender: F)
#   - Patient Patient329 (Age: 4, Gender: F)
#
# Room 88 (RoomNum: 489, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 89 (RoomNum: 490, Dept: 4, Capacity: 4, Gender: N):
#   - Patient Patient135 (Age: 0, Gender: M)
#   - Patient Patient189 (Age: 15, Gender: M)
#   - Patient Patient196 (Age: 12, Gender: F)
#   - Patient Patient213 (Age: 4, Gender: M)
#
# Room 90 (RoomNum: 491, Dept: 4, Capacity: 4, Gender: F):
#   - Patient Patient202 (Age: 16, Gender: F)
#   - Patient Patient261 (Age: 43, Gender: F)
#   - Patient Patient298 (Age: 39, Gender: F)
#   - Patient Patient305 (Age: 83, Gender: F)
#
# Room 91 (RoomNum: 492, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient214 (Age: 42, Gender: F)
#   - Patient Patient221 (Age: 37, Gender: M)
#   - Patient Patient319 (Age: 85, Gender: F)
#
# Room 92 (RoomNum: 493, Dept: 4, Capacity: 4, Gender: F):
#   - Patient Patient278 (Age: 29, Gender: F)
#
# Room 93 (RoomNum: 494, Dept: 4, Capacity: 4, Gender: D):
#   (empty)
#
# Room 94 (RoomNum: 495, Dept: 4, Capacity: 4, Gender: N):
#   (empty)
#
# Room 95 (RoomNum: 496, Dept: 4, Capacity: 4, Gender: N):
#   - Patient Patient283 (Age: 24, Gender: M)
#
# Room 96 (RoomNum: 497, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 97 (RoomNum: 498, Dept: 4, Capacity: 4, Gender: F):
#   - Patient Patient192 (Age: 50, Gender: F)
#   - Patient Patient208 (Age: 13, Gender: F)
#   - Patient Patient258 (Age: 21, Gender: F)
#   - Patient Patient262 (Age: 46, Gender: F)
#
# Room 98 (RoomNum: 499, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 99 (RoomNum: 4100, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient272 (Age: 2, Gender: F)
#   - Patient Patient295 (Age: 40, Gender: F)
#
# Room 100 (RoomNum: 4101, Dept: 4, Capacity: 4, Gender: M):
#   - Patient Patient274 (Age: 8, Gender: M)
#
# Room 101 (RoomNum: 4102, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 102 (RoomNum: 4103, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 103 (RoomNum: 4104, Dept: 4, Capacity: 4, Gender: M):
#   (empty)
#
# Room 104 (RoomNum: 4105, Dept: 4, Capacity: 4, Gender: D):
#   - Patient Patient222 (Age: 17, Gender: M)
#   - Patient Patient228 (Age: 7, Gender: M)
#   - Patient Patient233 (Age: 12, Gender: F)
#   - Patient Patient279 (Age: 14, Gender: M)
#
#  Solving for Day 7
# Patients present: 254
